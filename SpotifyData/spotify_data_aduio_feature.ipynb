# %%
# The code is coming from https://github.com/eric-ruzzo/spotify_popularity_analysis/blob/master/api_analysis.ipynb
# We apply some changes to retrieve all the features we want for Goergia Tech CS4641 Class Project

# %%
# Import dependencies
# spotipy is a library with methods that call the Spotify API

import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
# from config import client_id, secret, sql_pw

# %%
# Establish connection to Spotify
client_id = '46cd1adb58534beeaef6b9db30e96bd4'
secret = '90fd676b2c4b4c738a2e4e2ce362eab8'

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Create empty lists to store data from API calls

artist_name = []
track_name = []
track_id = []
popularity = []
artist_id = []

# 2020, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021

# Run a for loop to call the API multiple times for a list of tracks
# Starter code from a similar project:
# https://tgel0.github.io/blog/spotify-data-project-part-1-from-data-retrieval-to-first-insights/

# i represents each call of the Spotify search API, range is maximum results, step 50 represents 50 results per search
for i in range(0, 1000, 50):

    # Save results of each search as a variable. Limit search to 50 results, use offset to skip previous result of iteration
    
    track_results = sp.search(q='year:2010', type='track', limit=50, offset=i)
        
    
    # Loop through each result to find values for selected fields
    # Enumerate creates a tuple of each track result for iteration. Example: (0, J. Cole), (1, Ariana Grande), etc.
    for i, t in enumerate(track_results['tracks']['items']):
        
        artist_id.append(t['artists'][0]['id'])
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        
        popularity.append(t['popularity'])

# %%
sp.artist('7bXgB6jMjp9ATFy66eO08Z')

# %%
artist_id_genre = []   
# Create empty list for genre of each artist
genres = []
cntr = {}


# Loop through artist id list, calling API for each artist id
for artist in range(0,1000):
    
    

    artist_id_genre.append(artist_id[artist])
    
    # sp.artist calls Spotify API using spotipy library to find artist
    artist_results = sp.artist(artist_id[artist])
    
    # Append list of genres from results to genres list
    genres.append(artist_results["genres"])
    for gn in artist_results["genres"]:
        cntr[gn] = 1 + cntr.get(gn, 0)

# %%
# Create empty lists to store audio feature values

# Genre, artist_name, track_name, track_id, popularity, 
# acousticness, danceability, duration_ms, energy, instrumentalness, key, 
# liveness, loudness, mode, speechiness, tempo, time_signature, valence

acousticness = []
danceability = []
duration_ms = []
energy = []
instrumentalness = []
key = []
liveness = []
loudness = []
mode = []
speechiness = []
tempo = []
time_signature = []
valence = []


# Loop through track id list to find audio features for each track
for track in range(0, 1000):
    
    # Append selected values to corresponding lists
    try:
        audio_features = sp.audio_features(track_id[track])
        
        acousticness.append(audio_features[0]["acousticness"])
        danceability.append(audio_features[0]["danceability"])
        duration_ms.append(audio_features[0]["duration_ms"])
        energy.append(audio_features[0]["energy"])
        instrumentalness.append(audio_features[0]["instrumentalness"])
        key.append(audio_features[0]["key"])
        liveness.append(audio_features[0]["liveness"])
        mode.append(audio_features[0]["mode"])
        loudness.append(audio_features[0]["loudness"])
        tempo.append(audio_features[0]["tempo"])
        time_signature.append(audio_features[0]["time_signature"])
        speechiness.append(audio_features[0]["speechiness"])
        valence.append(audio_features[0]["valence"])
        
        
    
    # Error results if there are no features available. Use try/except to set value to 0 when there is an error
    except TypeError:
        acousticness.append(0)
        danceability.append(0)
        duration_ms.append(0)
        energy.append(0)
        instrumentalness.append(0)
        key.append(0)
        liveness.append(0)
        mode.append(0)
        loudness.append(0)
        tempo.append(0)
        time_signature.append(0)
        speechiness.append(0)
        valence.append(0)

# %%
features_df = pd.DataFrame({ "Artist Name": artist_name, 
                            "Artist_id": artist_id,
                            "Track Name":track_name, 
                            "Track ID": track_id,
                            "Popularity": popularity, 
                            
                            "acousticness": acousticness, 
                            "Danceability":danceability, 
                            "Duration_ms": duration_ms, 
                            "Energy":energy, 
                            "Instrumentalness": instrumentalness, 
                            "Key": key, 
                            "Liveness": liveness,
                            "Mode": mode,
                            "Loudness":loudness,
                            "Tempo": tempo,
                            "Time_signature": time_signature,
                            "Speechiness": speechiness,
                            "Valence":valence })

# Sort by Popularity score in descending order
features_df = features_df.sort_values(by=["Popularity"], ascending=False).reset_index()

features_df.head()
# Out:
#    index     Artist Name               Artist_id                Track Name  \
# 0      8  Patrick Watson  7bPs6jf983f0bjRAt1yxDM  Je te laisserai des mots
# 1     32          Plan B  2jSGzJw0ebJLu7OLVSOcBP             Es un Secreto
# 2     14          Eminem  7dGJo4pcD2V6oG8kP0tJRR      Love The Way You Lie
# 3      0      Mac Miller  4LLpKhyESsyAXpc4laK94U                 The Spins
# 4     13           Train  3FUY2gzHeIiaesXtOAdB7A          Hey, Soul Sister
#
#                  Track ID  Popularity  acousticness  Danceability  \
# 0  0V5cvmTKsYmF5FmGGEAfmS          84        0.9890         0.303
# 1  0R7DSnSibvuE4PEHqUayqf          83        0.0951         0.836
# 2  15JINEqzVMv3SvJTAXAKED          82        0.2410         0.749
# 3  51pshtuYkgUQnt5huMPbKL          81        0.0135         0.794
# 4  4HlFJV71xXKIGcU3kRyttv          81        0.1850         0.673
#
#    Duration_ms  Energy  Instrumentalness  Key  Liveness  Mode  Loudness  \
# 0       160853   0.187          0.489000    2    0.1010     1   -16.757
# 1       190564   0.777          0.000002    6    0.0561     0    -5.376
# 2       263373   0.925          0.000000   10    0.5200     1    -5.034
# 3       195873   0.766          0.000000    9    0.0785     0    -3.894
# 4       216773   0.886          0.000000    1    0.0826     0    -4.440
#
#      Tempo  Time_signature  Speechiness  Valence
# 0  132.731               4       0.0356    0.213
# 1   94.977               4       0.0439    0.504
# 2   86.989               4       0.2270    0.641
# 3  127.007               4       0.0377    0.550
# 4   97.012               4       0.0431    0.795

# %%
genre_df = pd.DataFrame({"Artist_id": artist_id_genre, "Genre": genres})
genre_df_2 = genre_df.drop_duplicates(subset=["Artist_id"], keep=False).reset_index()

new_data = pd.merge(features_df, genre_df_2, on = 'Artist_id')
new_data = new_data.drop(['index_x', 'index_y'], axis = 1)
new_data = new_data.sort_values(by=["Popularity"], ascending=False)

new_data.to_csv("audio_features_2010.csv", index=False)

# %%
new_data
# Out:
#           Artist Name               Artist_id                 Track Name  \
# 0      Patrick Watson  7bPs6jf983f0bjRAt1yxDM   Je te laisserai des mots
# 1               Nelly  2gBjLmx6zQnFGQJCAQpRgw               Just A Dream
# 2        Daddy Yankee  4VMYDCV2IEDYJArk749S6m               La Despedida
# 3        Juan Gabriel  2MRBDr0crHWE5JwPceFncq  ¿Por Qué Me Haces Llorar?
# 4            Kavinsky  0UF7XLthtbSF2Eur7559oV                  Nightcall
# ..                ...                     ...                        ...
# 288           MercyMe  6APm8EjxOHSYM5B4i3vT3q                       Move
# 289     Steve Winwood  5gxynDEKwNDgxGJmJjZyte           The Finer Things
# 290         The Drums  0p5axeJsbtTCXBrRVoKjwu            Lets Go Surfing
# 291  Krysta Rodriguez  7achJdkPpg7LVBU4ZvdlZA                     Pulled
# 292    The High Kings  6wXjctGBzxkT0ghwfQ8FC0            Red Is The Rose
#
#                    Track ID  Popularity  acousticness  Danceability  \
# 0    0V5cvmTKsYmF5FmGGEAfmS          84       0.98900         0.303
# 1    3ZdJffjzJWFimSQyxgGIxN          74       0.04210         0.531
# 2    33a2zTGZocgU9XVDDILHM3          73       0.09090         0.745
# 3    68pE8830rWrd5LSSfKcRqn          72       0.03740         0.647
# 4    0U0ldCRmgCqhVvD6ksG63j          72       0.00842         0.532
# ..                      ...         ...           ...           ...
# 288  42lb5Ne9DymiyPqX9KGOoq          47       0.01620         0.623
# 289  0qrOEuhMXqAyMMyfOCZ2yC          47       0.17900         0.782
# 290  6l6LgnyNHL3U6UgSx5Aiph          47       0.20900         0.577
# 291  6W6mfGp42e0npejwRfK5Mt          47       0.77200         0.509
# 292  4nqisfhqUZXEN5g2XeJBAt          46       0.89700         0.503
#
#      Duration_ms  Energy  Instrumentalness  Key  Liveness  Mode  Loudness  \
# 0         160853   0.187          0.489000    2    0.1010     1   -16.757
# 1         237800   0.752          0.000000    1    0.1200     1    -6.161
# 2         202827   0.994          0.054600    2    0.0684     0    -2.194
# 3         182880   0.477          0.000010    0    0.1270     1    -8.157
# 4         258413   0.874          0.012000    9    0.4520     0    -5.183
# ..           ...     ...               ...  ...       ...   ...       ...
# 288       178067   0.864          0.000002    9    0.2420     0    -5.541
# 289       251200   0.713          0.032100    2    0.1050     0    -6.999
# 290       175427   0.814          0.000525    1    0.0773     1    -5.694
# 291       179293   0.476          0.000000    0    0.2880     1    -7.958
# 292       191827   0.132          0.000000    4    0.1500     1   -10.852
#
#        Tempo  Time_signature  Speechiness  Valence  \
# 0    132.731               4       0.0356    0.213
# 1     89.917               4       0.0305    0.103
# 2    122.049               4       0.0497    0.972
# 3    112.041               4       0.0342    0.793
# 4     91.038               4       0.0482    0.361
# ..       ...             ...          ...      ...
# 288  106.011               4       0.0520    0.759
# 289  124.674               4       0.0325    0.572
# 290  174.059               4       0.0320    0.785
# 291  124.678               4       0.0710    0.495
# 292  111.484               1       0.0428    0.511
#
#                                                  Genre
# 0                        [indie folk, indie quebecois]
# 1    [dance pop, hip hop, pop rap, southern hip hop...
# 2              [latin hip hop, reggaeton, trap latino]
# 3    [cancion melodica, latin pop, mariachi, musica...
# 4    [alternative dance, electro house, electronica...
# ..                                                 ...
# 288  [ccm, christian alternative rock, christian in...
# 289  [album rock, art rock, classic rock, country r...
# 290  [brooklyn indie, indie rock, indie surf, moder...
# 291                                                 []
# 292  [celtic, celtic rock, irish folk, irish pub song]
#
# [293 rows x 19 columns]

# %%
cnts = [(gn, cnt) for gn, cnt in cntr.items()]
sortedCnts = sorted(cnts, key=lambda x: -x[1])
sortedCnts
# pop, rap, hip pop, country, rock, alternative metal, trap, edm, r&b, latino pop
# Out:
# [('pop', 205),
#  ('dance pop', 190),
#  ('rap', 138),
#  ('hip hop', 113),
#  ('pop rap', 92),
#  ('country', 77),
#  ('post-teen pop', 75),
#  ('country road', 75),
#  ('alternative metal', 65),
#  ('contemporary country', 64),
#  ('modern rock', 60),
#  ('rock', 60),
#  ('urban contemporary', 53),
#  ('nu metal', 53),
#  ('musica mexicana', 50),
#  ('southern hip hop', 45),
#  ('trap', 37),
#  ('pop punk', 36),
#  ('edm', 35),
#  ('r&b', 32),
#  ('post-grunge', 32),
#  ('latin pop', 31),
#  ('screamo', 30),
#  ('atl hip hop', 29),
#  ('modern country rock', 28),
#  ('norteno', 28),
#  ('indie rock', 27),
#  ('latin hip hop', 27),
#  ('tropical', 27),
#  ('pop rock', 26),
#  ('gangster rap', 25),
#  ('ranchera', 25),
#  ('indietronica', 24),
#  ('metalcore', 24),
#  ('nueva musica mexicana', 23),
#  ('hip pop', 22),
#  ('neo mellow', 22),
#  ('canadian pop', 22),
#  ('electropop', 22),
#  ('dirty south rap', 21),
#  ('alternative rock', 21),
#  ('chicago rap', 20),
#  ('alternative dance', 20),
#  ('pittsburgh rap', 19),
#  ('alternative hip hop', 18),
#  ('metropopolis', 18),
#  ('new americana', 18),
#  ('barbadian pop', 17),
#  ('detroit hip hop', 16),
#  ('ohio hip hop', 16),
#  ('stomp and holler', 16),
#  ('banda', 16),
#  ('indie folk', 15),
#  ('reggaeton', 15),
#  ('christian rock', 15),
#  ('indie pop', 14),
#  ('outlaw country', 14),
#  ('rap rock', 14),
#  ('rap metal', 14),
#  ('queens hip hop', 13),
#  ('hollywood', 13),
#  ('new rave', 13),
#  ('hard rock', 13),
#  ('canadian hip hop', 12),
#  ('toronto rap', 12),
#  ('soundtrack', 12),
#  ('emo', 12),
#  ('mellow gold', 12),
#  ('metal', 12),
#  ('corrido', 12),
#  ('neo soul', 12),
#  ('trap latino', 11),
#  ('contemporary r&b', 11),
#  ('country dawn', 11),
#  ('texas country', 11),
#  ('uk pop', 11),
#  ('roots rock', 11),
#  ('electronica', 11),
#  ('filter house', 11),
#  ('country rock', 11),
#  ('pop dance', 11),
#  ('baroque pop', 11),
#  ('bachata', 10),
#  ('red dirt', 10),
#  ('pop emo', 10),
#  ('worship', 10),
#  ('conscious hip hop', 10),
#  ('modern alternative rock', 9),
#  ('uk alternative pop', 9),
#  ('miami hip hop', 9),
#  ('mexican pop', 9),
#  ('boy band', 9),
#  ('classic rock', 9),
#  ('orchestral soundtrack', 9),
#  ('ccm', 9),
#  ('christian alternative rock', 9),
#  ('christian music', 9),
#  ('blues rock', 8),
#  ('garage rock', 8),
#  ('modern blues rock', 8),
#  ('punk blues', 8),
#  ('album rock', 8),
#  ('soft rock', 8),
#  ('electro', 8),
#  ('reggae rock', 8),
#  ('classical', 8),
#  ('singer-songwriter', 8),
#  ('bluegrass', 7),
#  ('progressive bluegrass', 7),
#  ('electro house', 7),
#  ('tejano', 7),
#  ('la indie', 7),
#  ('art rock', 7),
#  ('new wave pop', 7),
#  ('reggae fusion', 7),
#  ('redneck', 7),
#  ('neon pop punk', 7),
#  ('permanent wave', 7),
#  ('south carolina hip hop', 6),
#  ('europop', 6),
#  ('melodic metalcore', 6),
#  ('canadian indie', 6),
#  ('art pop', 6),
#  ('rock en espanol', 6),
#  ('west coast rap', 6),
#  ('pixie', 6),
#  ('cumbia sonidera', 6),
#  ('puerto rican pop', 5),
#  ('modern southern rock', 5),
#  ('neo-traditional bluegrass', 5),
#  ('colombian pop', 5),
#  ('mariachi', 5),
#  ('canadian rock', 5),
#  ('latin arena pop', 5),
#  ('new romantic', 5),
#  ('world worship', 5),
#  ('latin alternative', 5),
#  ('acoustic pop', 5),
#  ('mexican hip hop', 5),
#  ('narco rap', 5),
#  ('compositional ambient', 5),
#  ('duranguense', 5),
#  ('grupera', 5),
#  ('quiet storm', 5),
#  ('chillwave', 5),
#  ('oklahoma country', 5),
#  ('trip hop', 5),
#  ('weirdcore', 4),
#  ('modern folk rock', 4),
#  ('country pop', 4),
#  ('eurodance', 4),
#  ('dream pop', 4),
#  ('new orleans rap', 4),
#  ('swedish electropop', 4),
#  ('disney', 4),
#  ('movie tunes', 4),
#  ('viral rap', 4),
#  ('comic', 4),
#  ('german soundtrack', 4),
#  ('disco', 4),
#  ('black americana', 4),
#  ('hardcore hip hop', 4),
#  ('romanian house', 4),
#  ('romanian pop', 4),
#  ('heartland rock', 4),
#  ('lilith', 4),
#  ('dance-punk', 4),
#  ('alabama rap', 4),
#  ('british soundtrack', 4),
#  ('jawaiian', 4),
#  ('sierreno', 4),
#  ('funk', 4),
#  ('tierra caliente', 4),
#  ('australian dance', 4),
#  ('nu disco', 4),
#  ('rap conciencia', 4),
#  ('downtempo', 4),
#  ('philly indie', 3),
#  ('baltimore indie', 3),
#  ('dreamo', 3),
#  ('modern dream pop', 3),
#  ('old school atlanta hip hop', 3),
#  ('danish metal', 3),
#  ('danish rock', 3),
#  ('sad sierreno', 3),
#  ('scandipop', 3),
#  ('swedish pop', 3),
#  ('yacht rock', 3),
#  ('bubblegum pop', 3),
#  ('big room', 3),
#  ('brostep', 3),
#  ('dance rock', 3),
#  ('electronic rock', 3),
#  ('reggae', 3),
#  ('cumbia', 3),
#  ('j-pop', 3),
#  ('j-poprock', 3),
#  ('g funk', 3),
#  ('salsa', 3),
#  ('candy pop', 3),
#  ('indie pop rap', 3),
#  ('philly rap', 3),
#  ('country rap', 3),
#  ('classic sierreno', 3),
#  ('adult standards', 3),
#  ('brill building pop', 3),
#  ('glam metal', 3),
#  ('escape room', 3),
#  ('noise pop', 3),
#  ('indie soul', 3),
#  ('power metal', 3),
#  ('swedish metal', 3),
#  ('swedish power metal', 3),
#  ('quebec indie', 3),
#  ('east coast hip hop', 3),
#  ('glee club', 3),
#  ('neo-psychedelic', 3),
#  ('video game music', 3),
#  ('chamber pop', 3),
#  ('soul', 3),
#  ('alternative pop rock', 3),
#  ('nu jazz', 3),
#  ('alternative country', 3),
#  ('folk', 3),
#  ('indiecoustica', 3),
#  ('asian american hip hop', 2),
#  ('bubblegum dance', 2),
#  ('german techno', 2),
#  ('melbourne bounce international', 2),
#  ('horror synth', 2),
#  ('auckland indie', 2),
#  ('kiwi rock', 2),
#  ('uk metalcore', 2),
#  ('neo-synthpop', 2),
#  ('post-screamo', 2),
#  ('beatlesque', 2),
#  ('australian pop', 2),
#  ('electro latino', 2),
#  ('electropowerpop', 2),
#  ('house', 2),
#  ('tropical house', 2),
#  ('argentine reggae', 2),
#  ('argentine rock', 2),
#  ('belgian pop', 2),
#  ('g-house', 2),
#  ('afrofuturism', 2),
#  ('swamp rock', 2),
#  ('complextro', 2),
#  ('roots reggae', 2),
#  ('k-pop', 2),
#  ('cali rap', 2),
#  ('symphonic rock', 2),
#  ('jam band', 2),
#  ('bakersfield sound', 2),
#  ('futuristic swag', 2),
#  ('irish rock', 2),
#  ('northern irish indie', 2),
#  ('piano rock', 2),
#  ('country gospel', 2),
#  ('corridos alternativos', 2),
#  ('classic girl group', 2),
#  ('doo-wop', 2),
#  ('vocal harmony group', 2),
#  ('houston rap', 2),
#  ('glam rock', 2),
#  ('bow pop', 2),
#  ('cello', 2),
#  ('finnish metal', 2),
#  ('sacramento indie', 2),
#  ('brooklyn indie', 2),
#  ('indie surf', 2),
#  ("children's music", 2),
#  ('oakland hip hop', 2),
#  ('progressive electro house', 2),
#  ('cumbia del sureste', 2),
#  ('latin afrobeat', 2),
#  ('puerto rican rock', 2),
#  ('underground hip hop', 2),
#  ('canadian metal', 2),
#  ('classic canadian rock', 2),
#  ('boom bap espanol', 2),
#  ('rap politico', 2),
#  ('venezuelan hip hop', 2),
#  ('crunk', 2),
#  ('gruperas inmortales', 2),
#  ('early romantic era', 2),
#  ('polish classical', 2),
#  ('celtic rock', 2),
#  ('canadian electronic', 2),
#  ('progressive house', 2),
#  ('pop r&b', 2),
#  ('australian electropop', 2),
#  ('electroclash', 2),
#  ('progressive post-hardcore', 2),
#  ('bachata dominicana', 2),
#  ('gospel', 2),
#  ('minimalism', 2),
#  ('late romantic era', 2),
#  ('russian romanticism', 2),
#  ('sleep', 2),
#  ('big beat', 2),
#  ('australian psych', 2),
#  ('ninja', 2),
#  ('ambient', 2),
#  ('intelligent dance music', 2),
#  ('folk rock', 2),
#  ('livetronica', 2),
#  ('political hip hop', 2),
#  ('madchester', 2),
#  ('new wave', 2),
#  ('post-punk', 2),
#  ('uk post-punk', 2),
#  ('bay area indie', 2),
#  ('deep new americana', 2),
#  ('j-rock', 2),
#  ('experimental', 2),
#  ('jazztronica', 2),
#  ('filmi', 2),
#  ('modern bollywood', 2),
#  ('christian indie', 2),
#  ('indie quebecois', 1),
#  ('australian indie folk', 1),
#  ('st louis rap', 1),
#  ('swedish synthpop', 1),
#  ('welsh metal', 1),
#  ('cancion melodica', 1),
#  ('chicago bop', 1),
#  ('australian country', 1),
#  ('disco house', 1),
#  ('vocal house', 1),
#  ('canadian latin', 1),
#  ('k-pop girl group', 1),
#  ('dancehall', 1),
#  ('cumbia salvadorena', 1),
#  ('musica costena', 1),
#  ('progressive rock', 1),
#  ('duluth indie', 1),
#  ('broadway', 1),
#  ('fake', 1),
#  ('cowboy western', 1),
#  ('ambeat', 1),
#  ('early avant garde', 1),
#  ('early modern classical', 1),
#  ('impressionism', 1),
#  ('post-romantic era', 1),
#  ('welsh indie', 1),
#  ('welsh rock', 1),
#  ('alternative r&b', 1),
#  ('kansas city hip hop', 1),
#  ('canadian singer-songwriter', 1),
#  ('ectofolk', 1),
#  ('new jack swing', 1),
#  ('pop soul', 1),
#  ('sleaze rock', 1),
#  ('industrial rock', 1),
#  ('arkansas country', 1),
#  ('anime', 1),
#  ('otacore', 1),
#  ('grime', 1),
#  ('experimental pop', 1),
#  ('banjo', 1),
#  ('jamgrass', 1),
#  ('midwest americana', 1),
#  ('funk metal', 1),
#  ('minnesota hip hop', 1),
#  ('bass trap', 1),
#  ('classic dubstep', 1),
#  ('electronic trap', 1),
#  ('vapor twitch', 1),
#  ('classic soundtrack', 1),
#  ('theme', 1),
#  ('modern indie folk', 1),
#  ('stomp and flutter', 1),
#  ('aussietronica', 1),
#  ('latin rock', 1),
#  ('mexican rock', 1),
#  ('modern salsa', 1),
#  ('rap latina', 1),
#  ('nyc rap', 1),
#  ('garage rock revival', 1),
#  ('chilena', 1),
#  ('dark cabaret', 1),
#  ('steampunk', 1),
#  ('christian hard rock', 1),
#  ('hyphy', 1),
#  ('roots americana', 1),
#  ('latin christian', 1),
#  ('rock cristiano', 1),
#  ('atlanta indie', 1),
#  ('experimental rock', 1),
#  ('garage psych', 1),
#  ('lo-fi', 1),
#  ('noise rock', 1),
#  ('shoegaze', 1),
#  ('mississippi hip hop', 1),
#  ('indie poptimism', 1),
#  ('shimmer pop', 1),
#  ('talent show', 1),
#  ('reggaeton flow', 1),
#  ('jacksonville indie', 1),
#  ('australian reggae fusion', 1),
#  ('baroque', 1),
#  ('early music', 1),
#  ('german baroque', 1),
#  ('pirate', 1),
#  ('shanty', 1),
#  ('vancouver punk', 1),
#  ('dark synthpop', 1),
#  ('modern ska punk', 1),
#  ('punk', 1),
#  ('ska', 1),
#  ('ska punk', 1),
#  ('skate punk', 1),
#  ('socal pop punk', 1),
#  ('italian disco', 1),
#  ('synthpop', 1),
#  ('minneapolis sound', 1),
#  ('post-disco', 1),
#  ('epicore', 1),
#  ('east coast reggae', 1),
#  ('american contemporary classical', 1),
#  ('contemporary classical', 1),
#  ('trancecore', 1),
#  ('classic soul', 1),
#  ('retro soul', 1),
#  ('southern soul', 1),
#  ('australian rock', 1),
#  ('american modern classical', 1),
#  ('environmental', 1),
#  ('seattle hip hop', 1),
#  ('healing', 1),
#  ('high vibe', 1),
#  ('kirtan', 1),
#  ('meditation', 1),
#  ('shamanic', 1),
#  ('post-rock', 1),
#  ('cosmic american', 1),
#  ('merseybeat', 1),
#  ('rock-and-roll', 1),
#  ('rockabilly', 1),
#  ('sunshine pop', 1),
#  ('surf music', 1),
#  ('chicago indie', 1),
#  ('breakbeat', 1),
#  ('classical piano', 1),
#  ('russian classical piano', 1),
#  ('reggae en espanol', 1),
#  ('swedish americana', 1),
#  ('swedish singer-songwriter', 1),
#  ('lds', 1),
#  ('pink noise', 1),
#  ('idol', 1),
#  ('nashville indie', 1),
#  ('dallas indie', 1),
#  ('power pop', 1),
#  ('alternative roots rock', 1),
#  ('modern hard rock', 1),
#  ('birmingham metal', 1),
#  ('modern funk', 1),
#  ('japanese emo', 1),
#  ('visual kei', 1),
#  ('tempe indie', 1),
#  ('j-acoustic', 1),
#  ('japanese singer-songwriter', 1),
#  ('bolero', 1),
#  ('bolero mexicano', 1),
#  ('acid rock', 1),
#  ('classic garage rock', 1),
#  ('freakbeat', 1),
#  ('protopunk', 1),
#  ('psychedelic rock', 1),
#  ("women's music", 1),
#  ('korean r&b', 1),
#  ('nashville americana', 1),
#  ('boston rock', 1),
#  ('jazz boom bap', 1),
#  ('slovenian electronic', 1),
#  ('desi pop', 1),
#  ('sufi', 1),
#  ('christian uplift', 1),
#  ('glitch', 1),
#  ('glitch hop', 1),
#  ('hands up', 1),
#  ('italo dance', 1),
#  ('christian metal', 1),
#  ('viral pop', 1),
#  ('washington indie', 1),
#  ('new age', 1),
#  ('new age piano', 1),
#  ('jazz pop', 1),
#  ('lounge', 1),
#  ('anthem worship', 1),
#  ('deep ccm', 1),
#  ('experimental ambient', 1),
#  ('fourth world', 1),
#  ('panamanian pop', 1),
#  ('pop peruano', 1),
#  ('pop reggaeton', 1),
#  ('celtic', 1),
#  ('irish folk', 1),
#  ('irish pub song', 1),
#  ('grunge', 1),
#  ('show tunes', 1),
#  ('bossbeat', 1),
#  ('indian instrumental', 1),
#  ('west coast reggae', 1),
#  ('folktronica', 1)]
